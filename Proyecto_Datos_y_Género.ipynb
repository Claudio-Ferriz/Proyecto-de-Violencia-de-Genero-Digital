# %% [markdown]
# <a href="https://colab.research.google.com/github/Claudio-Ferriz/Proyecto-de-Violencia-de-Genero-Digital/blob/main/Proyecto_Datos_y_G%C3%A9nero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Librerías

# %%
# Importación y ejecución de las librerías de Python para el análisis y modelado
# de datos.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Carga de Datos

# %%
# Generación del dataframe referido a Silencios Digitales el cual
# se encuentra en formato excel importando desde el repositorio
# github del proyecto.


df_sd = pd.read_excel('https://github.com/Claudio-Ferriz/Proyecto-de-Violencia-de-Genero-Digital/raw/refs/heads/main/BBDD%20Silencios%20Digitales%20(compartida%20UBA).xlsx')

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Dataframes

# %%
df_sd
# Out:
#               Marca temporal 1. Edad             2. ¿En qué provincia vivís?  \
# 0    2025-09-12 13:36:43.356      26                     Santiago del Estero
# 1    2025-09-12 08:58:43.244      52  Ciudad Autónoma de Buenos Aires (CABA)
# 2    2025-09-11 19:35:41.708      28  Ciudad Autónoma de Buenos Aires (CABA)
# 3    2025-09-11 12:55:54.372      26  Ciudad Autónoma de Buenos Aires (CABA)
# 4    2025-09-11 12:52:37.716      34  Ciudad Autónoma de Buenos Aires (CABA)
# ...                      ...     ...                                     ...
# 1417 2025-11-29 07:19:05.984      43                            Buenos Aires
# 1418 2025-11-29 07:25:37.466      43  Ciudad Autónoma de Buenos Aires (CABA)
# 1419 2025-11-29 07:36:39.413      42                                 Neuquén
# 1420 2025-11-29 07:42:48.145      31                               Río Negro
# 1421 2025-11-29 08:04:09.824      39                            Buenos Aires
#
#      3. ¿Cuántas horas por día usás internet, en promedio?  \
# 0                                     Entre 2 y 3 horas
# 1                                     Entre 4 y 5 horas
# 2                                     Entre 5 y 6 horas
# 3                                        Más de 6 horas
# 4                                     Entre 1 y 2 horas
# ...                                                 ...
# 1417                                  Entre 3 y 4 horas
# 1418                                  Entre 4 y 5 horas
# 1419                                     Más de 6 horas
# 1420                                  Entre 3 y 4 horas
# 1421                                  Entre 4 y 5 horas
#
#      4. ¿Qué plataformas usás con mayor frecuencia en tu tiempo libre?  (Marcá todas las opciones que correspondan) NO INCLUYAS LAS QUE USES PARA TRABAJAR - SOLO TIEMPO LIBRE  \
# 0     WhatsApp, Instagram, Youtube, Chat GPT / Gemin...
# 1     WhatsApp, Instagram, Youtube, Chat GPT / Gemin...
# 2                  WhatsApp, Instagram, TikTok, Youtube
# 3      WhatsApp, Instagram, Youtube, Correo electrónico
# 4                WhatsApp, Instagram, Facebook, Youtube
# ...                                                 ...
# 1417                                 Instagram, Youtube
# 1418    WhatsApp, Facebook, Youtube, Correo electrónico
# 1419  WhatsApp, Instagram, Facebook, Youtube, Apps d...
# 1420                       WhatsApp, Instagram, Youtube
# 1421  WhatsApp, Instagram, Facebook, Youtube, Juegos...
#
#                      5. Si usas instagram, tu perfil es  \
# 0     Público y uso mejores amigos para cuestiones p...
# 1                                               Privado
# 2                                               Privado
# 3                                               Privado
# 4                                               Público
# ...                                                 ...
# 1417                                            Privado
# 1418                                            Público
# 1419                                            Privado
# 1420                                            Privado
# 1421  Público y uso mejores amigos para cuestiones p...
#
#      6. ¿Para qué usás redes sociales?  (Marcá todas las opciones que correspondan)  \
# 0     Para difundir actividades laborales o profesio...
# 1     Para difundir actividades laborales o profesio...
# 2                          Para divertirme y despejarme
# 3     Para divertirme y despejarme, Para conectar co...
# 4                          Para divertirme y despejarme
# ...                                                 ...
# 1417                       Para divertirme y despejarme
# 1418  Para divertirme y despejarme, Para difundir ac...
# 1419                       Para divertirme y despejarme
# 1420  Para divertirme y despejarme, Para difundir ac...
# 1421  Para divertirme y despejarme, Para difundir ac...
#
#      7. ¿Qué tan libre te sentís de publicar lo que querés en redes sociales o plataformas digitales? (Marcá todas las opciones que correspondan)  \
# 0     Evito publicar sobre ciertos temas porque ya h...
# 1     Evito publicar sobre política para no polemiza...
# 2     Evito publicar sobre política por temor a repe...
# 3     Evito publicar sobre política para no polemiza...
# 4     Evito publicar sobre política por temor a repe...
# ...                                                 ...
# 1417  Me cuesta mucho mostrar mi cuerpo por no ser h...
# 1418  Evito publicar sobre política por temor a repe...
# 1419  Evito publicar sobre política para no polemiza...
# 1420  Casi no uso redes sociales y por ende no publi...
# 1421  Evito publicar sobre política para no polemiza...
#
#      8. ¿Cuál es tu máximo nivel educativo alcanzado?  \
# 0                                  Terciario completo
# 1                                   Posgrado completo
# 2                            Universitario incompleto
# 3                            Universitario incompleto
# 4                            Universitario incompleto
# ...                                               ...
# 1417                                Posgrado completo
# 1418                                Posgrado completo
# 1419                               Terciario completo
# 1420                               Terciario completo
# 1421                           Universitario completo
#
#      9. ¿Con qué identidad de género te identificás?  ...  \
# 0                                              Mujer  ...
# 1                                              Mujer  ...
# 2                                              Mujer  ...
# 3                                              Varón  ...
# 4                                              Varón  ...
# ...                                              ...  ...
# 1417                                           Mujer  ...
# 1418                                           Mujer  ...
# 1419                                           Mujer  ...
# 1420                                           Mujer  ...
# 1421                                           Mujer  ...
#
#      25. ¿Realizaste cambios en el comportamiento digital después de lo sucedido? (Marcá todas las opciones que correspondan)  \
# 0                            Eliminé cuentas o perfiles
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                    No realicé cambios
# ...                                                 ...
# 1417                                                NaN
# 1418  Cambie foto de perfil. Ya no tengo una foto pr...
# 1419                                 No realicé cambios
# 1420                                                NaN
# 1421  Me censuré o dejé de publicar ciertos tipos de...
#
#      26.  ¿Qué efectos tuvo en vos haber vivido estas situaciones?   \
# 0     Me dio miedo y sobre todo asco por los conteni...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Entre amigos algunos chistes pueden pasar, no ...
# ...                                                 ...
# 1417                                                NaN
# 1418                                        Desgastante
# 1419  Empecé a desconfiar de esa persona y a sentirm...
# 1420                                                NaN
# 1421  Dejé de sentirme libre de comentar lo que quer...
#
#         27.  ¿Contaste lo sucedido a alguien?   \
# 0     Sí a mi espacio de militancia, activismo
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                   No, no se lo conté a nadie
# ...                                        ...
# 1417                                       NaN
# 1418                           Sí, a mi pareja
# 1419                No, no se lo conté a nadie
# 1420                                       NaN
# 1421                           Sí, a mi pareja
#
#      29. ¿Sabés cómo denunciar situaciones de violencia de género digital  (en plataformas, instituciones o con apoyo legal)?    \
# 0                                                    No
# 1                                                    Si
# 2                                                    No
# 3                                                    No
# 4                                                    No
# ...                                                 ...
# 1417                                    No estoy segurx
# 1418                                                 No
# 1419                                                 No
# 1420                                                 Si
# 1421                                                 Si
#
#      28. Realizaste alguna formación o te interiorizaste sobre seguridad digital en los últimos cinco años (por ejemplo, privacidad, contraseñas, configuración de cuentas)?  \
# 0                                                    Si
# 1                                                    Si
# 2                                                    No
# 3                                       No estoy segurx
# 4                                                    No
# ...                                                 ...
# 1417                                                 Si
# 1418                                                 No
# 1419                                                 No
# 1420                                                 No
# 1421                                                 No
#
#      29. ¿Qué tipo de medidas te parecerían útiles para prevenir o responder a la violencia de género digital? (Marcá todas las opciones que correspondan)  \
# 0     Capacitaciones para mejorar el manejo de confi...
# 1     Mayor control y respuesta por parte de las pla...
# 2     Capacitaciones para mejorar el manejo de confi...
# 3     Capacitaciones para mejorar el manejo de confi...
# 4     Campañas de concientización y prevención, Mayo...
# ...                                                 ...
# 1417  Capacitaciones para mejorar el manejo de confi...
# 1418        Acceso gratuito a apoyo legal y psicológico
# 1419  Capacitaciones para mejorar el manejo de confi...
# 1420  Mayor control y respuesta por parte de las pla...
# 1421  Capacitaciones para mejorar el manejo de confi...
#
#      30. ¿Cuánto sabés o entendés sobre las siguientes medidas de seguridad digital?   (Contraseñas seguras, autenticación en dos pasos o doble factor (2FA),  Redes privadas virtuales (VPN), etc?\n  \
# 0                                                   3.0
# 1                                                   5.0
# 2                                                   2.0
# 3                                                   3.0
# 4                                                   4.0
# ...                                                 ...
# 1417                                                2.0
# 1418                                                3.0
# 1419                                                1.0
# 1420                                                2.0
# 1421                                                4.0
#
#      31. Si alguna vez sufrieras una agresión en internet, ¿sentís que estás preparadx para proteger tu privacidad?  \
# 0                                                    Si
# 1                                          Parcialmente
# 2                                                    No
# 3                                          Parcialmente
# 4                                          Parcialmente
# ...                                                 ...
# 1417                                       Parcialmente
# 1418                                    No estoy segurx
# 1419                                                 No
# 1420                                       Parcialmente
# 1421                                       Parcialmente
#
#      32. ¿Te gustaría contarnos algo más en torno a tus vivencias en internet y la violencia de género facilitada por la tecnología?  \
# 0     Además de recibir constantes fotos de miembros...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1417                                                NaN
# 1418                                                NaN
# 1419           Las aplicaciones de citas son un horror
# 1420  Entre el 2020 y el 2022 me acosó un ex desde B...
# 1421  Dejé de jugar videojuegos online por el acoso ...
#
#      33. Si querés recibir el informe con los resultados de la encuesta, compartinos tu correo electrónico
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1417                                                NaN
# 1418                                                NaN
# 1419                                                NaN
# 1420                                                NaN
# 1421                                                NaN
#
# [1422 rows x 35 columns]

# %%
df_sd.columns.to_list()
# Out:
# ['Marca temporal',
#  '1. Edad',
#  '2. ¿En qué provincia vivís?',
#  '3. ¿Cuántas horas por día usás internet, en promedio?',
#  '4. ¿Qué plataformas usás con mayor frecuencia en tu tiempo libre?  (Marcá todas las opciones que correspondan) NO INCLUYAS LAS QUE USES PARA TRABAJAR - SOLO TIEMPO LIBRE',
#  '5. Si usas instagram, tu perfil es',
#  '6. ¿Para qué usás redes sociales?  (Marcá todas las opciones que correspondan)',
#  '7. ¿Qué tan libre te sentís de publicar lo que querés en redes sociales o plataformas digitales? (Marcá todas las opciones que correspondan)',
#  '8. ¿Cuál es tu máximo nivel educativo alcanzado?',
#  '9. ¿Con qué identidad de género te identificás?',
#  '10. ¿Cuál es tu orientación sexual?',
#  '11. ¿Participás o militás en alguna organización política, social o colectiva? (Marcar todas las opciones que correspondan) ',
#  '12. ¿Cuál de estas situaciones describe mejor tu realidad económica actual?',
#  '13. En los últimos 24 meses, ¿viviste algún intento de estafa?',
#  '14. ¿En los grupos de WhatsApp o Telegram en los que participás, circulan chistes, comentarios, imágenes o stickers que incluyan alguno de los siguientes contenidos? (Marcá todas las opciones que correspondan)  ',
#  '15. ¿En los últimos 24 meses, sufriste alguna situación de violencia de género en entornos digitales? \n\nLa violencia de género facilitada por la tecnología es cualquier conducta dirigida contra mujeres, niñas y otras personas en razón de su orientación sexual, identidad o expresión de género que cause daño y que sea cometida, facilitada o amplificada mediante el uso de tecnologías de la información y la comunicación (TIC).\nEste tipo de violencia incluye, la difusión no consentida de imágenes íntimas, las agresiones verbales en plataformas y el acoso virtual, amenazas, entre otras formas.',
#  '16. ¿En los últimos 24 meses, viviste alguna de las siguientes situaciones en entornos digitales? (Marcá todas las opciones que correspondan)  ',
#  '17. ¿En la pregunta anterior marcaste al menos una de las situaciones mencionadas?',
#  '18. ¿En qué espacios o plataformas ocurrió esta situación?  Si seleccionaste más de una situación en la pregunta anterior, te pedimos que a partir de ahora respondas pensando en aquella situación que te haya resultado más difícil o significativa.',
#  '19. ¿Sentís que la situación que viviste estuvo motivada por...',
#  '20. ¿Conocías a la persona o grupo que llevó adelante esta acción?',
#  '21. ¿Qué vínculo tenés/tenías vos con esa persona?',
#  '22. Más allá de lo que ocurrió en entornos digitales, ¿pasaron algunas de estas situaciones con tu pareja o ex pareja? ',
#  '23. ¿Denunciaste la situación? (Marcá todas las opciones que correspondan)',
#  '24. ¿Cómo describirías la situación de violencia que viviste?  (Marcá todas las opciones que correspondan) \nRecordá que tu respuesta es sobre la situación que te haya resultado más difícil o significativa.',
#  '25. ¿Realizaste cambios en el comportamiento digital después de lo sucedido? (Marcá todas las opciones que correspondan)',
#  '26.  ¿Qué efectos tuvo en vos haber vivido estas situaciones? ',
#  '27.  ¿Contaste lo sucedido a alguien? ',
#  '29. ¿Sabés cómo denunciar situaciones de violencia de género digital  (en plataformas, instituciones o con apoyo legal)?  ',
#  '28. Realizaste alguna formación o te interiorizaste sobre seguridad digital en los últimos cinco años (por ejemplo, privacidad, contraseñas, configuración de cuentas)?',
#  '29. ¿Qué tipo de medidas te parecerían útiles para prevenir o responder a la violencia de género digital? (Marcá todas las opciones que correspondan)',
#  '30. ¿Cuánto sabés o entendés sobre las siguientes medidas de seguridad digital?   (Contraseñas seguras, autenticación en dos pasos o doble factor (2FA),  Redes privadas virtuales (VPN), etc?\n',
#  '31. Si alguna vez sufrieras una agresión en internet, ¿sentís que estás preparadx para proteger tu privacidad?',
#  '32. ¿Te gustaría contarnos algo más en torno a tus vivencias en internet y la violencia de género facilitada por la tecnología?',
#  '33. Si querés recibir el informe con los resultados de la encuesta, compartinos tu correo electrónico ']

# %%
df_sd = df_sd.rename(columns={'1. Edad':'Edad','2. ¿En qué provincia vivís?':'Provincia','3. ¿Cuántas horas por día usás internet, en promedio?':'Uso promedio en horas por día de internet',
 '4. ¿Qué plataformas usás con mayor frecuencia en tu tiempo libre?  (Marcá todas las opciones que correspondan) NO INCLUYAS LAS QUE USES PARA TRABAJAR - SOLO TIEMPO LIBRE':'Plataforma más utilizada en el tiempo libre',
 '5. Si usas instagram, tu perfil es':'Tipo de perfil en Instagram',
 '6. ¿Para qué usás redes sociales?  (Marcá todas las opciones que correspondan)':'Uso de las redes sociales',
 '7. ¿Qué tan libre te sentís de publicar lo que querés en redes sociales o plataformas digitales? (Marcá todas las opciones que correspondan)':'Nivel de libertad para publicar en redes sociales o plataformas digitales',
 '8. ¿Cuál es tu máximo nivel educativo alcanzado?':'Nivel educativo alcanzado',
 '9. ¿Con qué identidad de género te identificás?':'Género',
 '10. ¿Cuál es tu orientación sexual?':'Orientación sexual',
 '11. ¿Participás o militás en alguna organización política, social o colectiva? (Marcar todas las opciones que correspondan) ':'Participación o militancia en organizaciones políticas, sociales o colectivas',
 '12. ¿Cuál de estas situaciones describe mejor tu realidad económica actual?':'Situación económica',
 '13. En los últimos 24 meses, ¿viviste algún intento de estafa?':'Intento de estafa en los últimos 24 meses',
 '14. ¿En los grupos de WhatsApp o Telegram en los que participás, circulan chistes, comentarios, imágenes o stickers que incluyan alguno de los siguientes contenidos? (Marcá todas las opciones que correspondan)  ':'Circulación de chistes, comentarios, imágenes o stickers en grupos de WhatsApp o Telegram',
 '15. ¿En los últimos 24 meses, sufriste alguna situación de violencia de género en entornos digitales? \n\nLa violencia de género facilitada por la tecnología es cualquier conducta dirigida contra mujeres, niñas y otras personas en razón de su orientación sexual, identidad o expresión de género que cause daño y que sea cometida, facilitada o amplificada mediante el uso de tecnologías de la información y la comunicación (TIC).\nEste tipo de violencia incluye, la difusión no consentida de imágenes íntimas, las agresiones verbales en plataformas y el acoso virtual, amenazas, entre otras formas.':'Situación de violencia de género en entornos digitales sufrida en los últimos 24 meses',
 '16. ¿En los últimos 24 meses, viviste alguna de las siguientes situaciones en entornos digitales? (Marcá todas las opciones que correspondan)  ': 'Situaciones de violencia de género en entornos digitales sufridas en los últimos 24 meses',
 '17. ¿En la pregunta anterior marcaste al menos una de las situaciones mencionadas?':'Si vivio o no alguna situación de violencia de género en entornos digitales',
 '18. ¿En qué espacios o plataformas ocurrió esta situación?  Si seleccionaste más de una situación en la pregunta anterior, te pedimos que a partir de ahora respondas pensando en aquella situación que te haya resultado más difícil o significativa.':'Espacios o plataformas donde ocurren estas situaciones',
 '19. ¿Sentís que la situación que viviste estuvo motivada por...':'Motivo de la situación vivida',
 '20. ¿Conocías a la persona o grupo que llevó adelante esta acción?':'Si existe conocimiento de la persona o grupo que llevo a cabo la acción',
 '21. ¿Qué vínculo tenés/tenías vos con esa persona?':'Vínculo qué tiene/tenía con esa persona',
 '22. Más allá de lo que ocurrió en entornos digitales, ¿pasaron algunas de estas situaciones con tu pareja o ex pareja? ':'Situaciones de violencia de género en entornos digitales con pareja o ex pareja',
 '23. ¿Denunciaste la situación? (Marcá todas las opciones que correspondan)': 'Denuncia de la situación',
 '24. ¿Cómo describirías la situación de violencia que viviste?  (Marcá todas las opciones que correspondan) \nRecordá que tu respuesta es sobre la situación que te haya resultado más difícil o significativa.':'Descripción de la situación de violencia vivida',
 '25. ¿Realizaste cambios en el comportamiento digital después de lo sucedido? (Marcá todas las opciones que correspondan)':'Cambios en el comportamiento digital luego de lo sucedido',
 '26.  ¿Qué efectos tuvo en vos haber vivido estas situaciones? ':'Efectos de haber vivido estas situaciones de violencia',
 '27.  ¿Contaste lo sucedido a alguien? ': 'Si conto lo sucedido a alguien',
 '29. ¿Sabés cómo denunciar situaciones de violencia de género digital  (en plataformas, instituciones o con apoyo legal)?  ':'Si sabe como denunciar situaciones de violencia de género digital',
 '28. Realizaste alguna formación o te interiorizaste sobre seguridad digital en los últimos cinco años (por ejemplo, privacidad, contraseñas, configuración de cuentas)?':'Si Realizo alguna formación o se interiorizo sobre seguridad digital en los últimos cinco años',
 '29. ¿Qué tipo de medidas te parecerían útiles para prevenir o responder a la violencia de género digital? (Marcá todas las opciones que correspondan)':'Tipo de medidas útiles para prevenir o responder a la violencia de género digital',
 '30. ¿Cuánto sabés o entendés sobre las siguientes medidas de seguridad digital?   (Contraseñas seguras, autenticación en dos pasos o doble factor (2FA),  Redes privadas virtuales (VPN), etc?\n':'Nivel de conocimiento o entendimiento de medidas de seguridad digital',
 '31. Si alguna vez sufrieras una agresión en internet, ¿sentís que estás preparadx para proteger tu privacidad?':' Nivel de preparación para proteger su privacidad',
 '32. ¿Te gustaría contarnos algo más en torno a tus vivencias en internet y la violencia de género facilitada por la tecnología?':'Vivencias en internet y violencia de género facilitada por la tecnología',
 '33. Si querés recibir el informe con los resultados de la encuesta, compartinos tu correo electrónico':'Si quiere recibir el informe con los resultados de la encuesta vía correo electrónico'})

# %%
df_sd = df_sd.drop(df_sd.columns[34], axis=1)

# %%
df_sd['Provincia'].unique()
# Out:
# array(['Santiago del Estero', 'Ciudad Autónoma de Buenos Aires (CABA)',
#        'Buenos Aires', 'Misiones', 'Santa Cruz', 'San Luis',
#        'Tierra del Fuego', 'Salta', 'Córdoba', 'Tucumán', 'San Juan',
#        'Corrientes', 'Santa Fe', 'Jujuy', 'Catamarca', 'Río Negro',
#        'Chaco', 'Mendoza', 'Chubut', 'La Rioja', 'Entre Ríos', 'Formosa',
#        'La Pampa', 'Neuquén'], dtype=object)

# %%
NOA = ['Santiago del Estero', 'Salta', 'Tucumán', 'Jujuy', 'Catamarca']

NEA = ['Misiones', 'Corrientes', 'Santa Fe', 'Chaco', 'Entre Ríos', 'Formosa']

Centro = ['Ciudad Autónoma de Buenos Aires (CABA)', 'Buenos Aires',  'Córdoba']

Cuyo = ['San Luis', 'San Juan', 'Mendoza', 'La Rioja']

Patagonia_Norte = ['Río Negro', 'La Pampa', 'Neuquén']

Patagonia_Sur = ['Santa Cruz', 'Tierra del Fuego', 'Chubut']

condiciones = [
    df_sd['Provincia'].isin(NOA),
    df_sd['Provincia'].isin(NEA),
    df_sd['Provincia'].isin(Centro),
    df_sd['Provincia'].isin(Cuyo),
    df_sd['Provincia'].isin(Patagonia_Norte),
    df_sd['Provincia'].isin(Patagonia_Sur)
]

df_sd['Región'] = np.select(condiciones,['NOA', 'NEA', 'Centro', 'Cuyo', 'Patagonia_Norte', 'Patagonia_Sur'], default= 'Otros')

# %%
df_sd
# Out:
#               Marca temporal Edad                               Provincia  \
# 0    2025-09-12 13:36:43.356   26                     Santiago del Estero
# 1    2025-09-12 08:58:43.244   52  Ciudad Autónoma de Buenos Aires (CABA)
# 2    2025-09-11 19:35:41.708   28  Ciudad Autónoma de Buenos Aires (CABA)
# 3    2025-09-11 12:55:54.372   26  Ciudad Autónoma de Buenos Aires (CABA)
# 4    2025-09-11 12:52:37.716   34  Ciudad Autónoma de Buenos Aires (CABA)
# ...                      ...  ...                                     ...
# 1417 2025-11-29 07:19:05.984   43                            Buenos Aires
# 1418 2025-11-29 07:25:37.466   43  Ciudad Autónoma de Buenos Aires (CABA)
# 1419 2025-11-29 07:36:39.413   42                                 Neuquén
# 1420 2025-11-29 07:42:48.145   31                               Río Negro
# 1421 2025-11-29 08:04:09.824   39                            Buenos Aires
#
#      Uso promedio en horas por día de internet  \
# 0                            Entre 2 y 3 horas
# 1                            Entre 4 y 5 horas
# 2                            Entre 5 y 6 horas
# 3                               Más de 6 horas
# 4                            Entre 1 y 2 horas
# ...                                        ...
# 1417                         Entre 3 y 4 horas
# 1418                         Entre 4 y 5 horas
# 1419                            Más de 6 horas
# 1420                         Entre 3 y 4 horas
# 1421                         Entre 4 y 5 horas
#
#             Plataforma más utilizada en el tiempo libre  \
# 0     WhatsApp, Instagram, Youtube, Chat GPT / Gemin...
# 1     WhatsApp, Instagram, Youtube, Chat GPT / Gemin...
# 2                  WhatsApp, Instagram, TikTok, Youtube
# 3      WhatsApp, Instagram, Youtube, Correo electrónico
# 4                WhatsApp, Instagram, Facebook, Youtube
# ...                                                 ...
# 1417                                 Instagram, Youtube
# 1418    WhatsApp, Facebook, Youtube, Correo electrónico
# 1419  WhatsApp, Instagram, Facebook, Youtube, Apps d...
# 1420                       WhatsApp, Instagram, Youtube
# 1421  WhatsApp, Instagram, Facebook, Youtube, Juegos...
#
#                             Tipo de perfil en Instagram  \
# 0     Público y uso mejores amigos para cuestiones p...
# 1                                               Privado
# 2                                               Privado
# 3                                               Privado
# 4                                               Público
# ...                                                 ...
# 1417                                            Privado
# 1418                                            Público
# 1419                                            Privado
# 1420                                            Privado
# 1421  Público y uso mejores amigos para cuestiones p...
#
#                               Uso de las redes sociales  \
# 0     Para difundir actividades laborales o profesio...
# 1     Para difundir actividades laborales o profesio...
# 2                          Para divertirme y despejarme
# 3     Para divertirme y despejarme, Para conectar co...
# 4                          Para divertirme y despejarme
# ...                                                 ...
# 1417                       Para divertirme y despejarme
# 1418  Para divertirme y despejarme, Para difundir ac...
# 1419                       Para divertirme y despejarme
# 1420  Para divertirme y despejarme, Para difundir ac...
# 1421  Para divertirme y despejarme, Para difundir ac...
#
#      Nivel de libertas para publicar en redes sociales o plataformas digitales  \
# 0     Evito publicar sobre ciertos temas porque ya h...
# 1     Evito publicar sobre política para no polemiza...
# 2     Evito publicar sobre política por temor a repe...
# 3     Evito publicar sobre política para no polemiza...
# 4     Evito publicar sobre política por temor a repe...
# ...                                                 ...
# 1417  Me cuesta mucho mostrar mi cuerpo por no ser h...
# 1418  Evito publicar sobre política por temor a repe...
# 1419  Evito publicar sobre política para no polemiza...
# 1420  Casi no uso redes sociales y por ende no publi...
# 1421  Evito publicar sobre política para no polemiza...
#
#      Nivel educativo alcanzado Género  ...  \
# 0           Terciario completo  Mujer  ...
# 1            Posgrado completo  Mujer  ...
# 2     Universitario incompleto  Mujer  ...
# 3     Universitario incompleto  Varón  ...
# 4     Universitario incompleto  Varón  ...
# ...                        ...    ...  ...
# 1417         Posgrado completo  Mujer  ...
# 1418         Posgrado completo  Mujer  ...
# 1419        Terciario completo  Mujer  ...
# 1420        Terciario completo  Mujer  ...
# 1421    Universitario completo  Mujer  ...
#
#      Cambios en el comportamiento digital luego de lo sucedido  \
# 0                            Eliminé cuentas o perfiles
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                    No realicé cambios
# ...                                                 ...
# 1417                                                NaN
# 1418  Cambie foto de perfil. Ya no tengo una foto pr...
# 1419                                 No realicé cambios
# 1420                                                NaN
# 1421  Me censuré o dejé de publicar ciertos tipos de...
#
#      Efectos de haber vivido estas situaciones de violencia  \
# 0     Me dio miedo y sobre todo asco por los conteni...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Entre amigos algunos chistes pueden pasar, no ...
# ...                                                 ...
# 1417                                                NaN
# 1418                                        Desgastante
# 1419  Empecé a desconfiar de esa persona y a sentirm...
# 1420                                                NaN
# 1421  Dejé de sentirme libre de comentar lo que quer...
#
#                 Si conto lo sucedido a alguien  \
# 0     Sí a mi espacio de militancia, activismo
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                   No, no se lo conté a nadie
# ...                                        ...
# 1417                                       NaN
# 1418                           Sí, a mi pareja
# 1419                No, no se lo conté a nadie
# 1420                                       NaN
# 1421                           Sí, a mi pareja
#
#      Si sabe como denunciar situaciones de violencia de género digital  \
# 0                                                    No
# 1                                                    Si
# 2                                                    No
# 3                                                    No
# 4                                                    No
# ...                                                 ...
# 1417                                    No estoy segurx
# 1418                                                 No
# 1419                                                 No
# 1420                                                 Si
# 1421                                                 Si
#
#      Si Realizo alguna formación o se interiorizo sobre seguridad digital en los últimos cinco años  \
# 0                                                    Si
# 1                                                    Si
# 2                                                    No
# 3                                       No estoy segurx
# 4                                                    No
# ...                                                 ...
# 1417                                                 Si
# 1418                                                 No
# 1419                                                 No
# 1420                                                 No
# 1421                                                 No
#
#      Tipo de medidas útiles para prevenir o responder a la violencia de género digital  \
# 0     Capacitaciones para mejorar el manejo de confi...
# 1     Mayor control y respuesta por parte de las pla...
# 2     Capacitaciones para mejorar el manejo de confi...
# 3     Capacitaciones para mejorar el manejo de confi...
# 4     Campañas de concientización y prevención, Mayo...
# ...                                                 ...
# 1417  Capacitaciones para mejorar el manejo de confi...
# 1418        Acceso gratuito a apoyo legal y psicológico
# 1419  Capacitaciones para mejorar el manejo de confi...
# 1420  Mayor control y respuesta por parte de las pla...
# 1421  Capacitaciones para mejorar el manejo de confi...
#
#      Nivel de conocimiento o entendimiento de medidas de seguridad digital  \
# 0                                                   3.0
# 1                                                   5.0
# 2                                                   2.0
# 3                                                   3.0
# 4                                                   4.0
# ...                                                 ...
# 1417                                                2.0
# 1418                                                3.0
# 1419                                                1.0
# 1420                                                2.0
# 1421                                                4.0
#
#       Nivel de preparación para proteger su privacidad  \
# 0                                                   Si
# 1                                         Parcialmente
# 2                                                   No
# 3                                         Parcialmente
# 4                                         Parcialmente
# ...                                                ...
# 1417                                      Parcialmente
# 1418                                   No estoy segurx
# 1419                                                No
# 1420                                      Parcialmente
# 1421                                      Parcialmente
#
#      Vivencias en internet y violencia de género facilitada por la tecnología  \
# 0     Además de recibir constantes fotos de miembros...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1417                                                NaN
# 1418                                                NaN
# 1419           Las aplicaciones de citas son un horror
# 1420  Entre el 2020 y el 2022 me acosó un ex desde B...
# 1421  Dejé de jugar videojuegos online por el acoso ...
#
#                Región
# 0                 NOA
# 1              Centro
# 2              Centro
# 3              Centro
# 4              Centro
# ...               ...
# 1417           Centro
# 1418           Centro
# 1419  Patagonia_Norte
# 1420  Patagonia_Norte
# 1421           Centro
#
# [1422 rows x 35 columns]

# %%
df_sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1422 entries, 0 to 1421
# Data columns (total 35 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   Marca temporal                                                                                  1422 non-null   datetime64[ns]
#  1   Edad                                                                                            1422 non-null   object
#  2   Provincia                                                                                       1422 non-null   object
#  3   Uso promedio en horas por día de internet                                                       1422 non-null   object
#  4   Plataforma más utilizada en el tiempo libre                                                     1422 non-null   object
#  5   Tipo de perfil en Instagram                                                                     1371 non-null   object
#  6   Uso de las redes sociales                                                                       1422 non-null   object
#  7   Nivel de libertas para publicar en redes sociales o plataformas digitales                       1422 non-null   object
#  8   Nivel educativo alcanzado                                                                       1422 non-null   object
#  9   Género                                                                                          1422 non-null   object
#  10  Orientación sexual                                                                              1422 non-null   object
#  11  Participación o militancia en organizaciones políticas, sociales o colectivas                   1422 non-null   object
#  12  Situación económica                                                                             1422 non-null   object
#  13  Intento de estafa en los últimos 24 meses                                                       1422 non-null   object
#  14  Circulación de chistes, comentarios, imágenes o stickers en grupos de WhatsApp o Telegram       1422 non-null   object
#  15  Situación de violencia de género en entornos digitales sufrida en los últimos 24 meses          1422 non-null   object
#  16  Situaciones de violencia de género en entornos digitales sufridas en los últimos 24 meses       1422 non-null   object
#  17  Si vivio o no alguna situación de violencia de género en entornos digitales                     1422 non-null   object
#  18  Espacios o plataformas donde ocurren estas situaciones                                          571 non-null    object
#  19  Motivo de la situación vivida                                                                   571 non-null    object
#  20  Si existe conocimiento de la persona o grupo que llevo a cabo la acción                         571 non-null    object
#  21  Vínculo qué tiene/tenía con esa persona                                                         223 non-null    object
#  22  Situaciones de violencia de género en entornos digitales con pareja o ex pareja                 55 non-null     object
#  23  Denuncia de la situación                                                                        571 non-null    object
#  24  Descripción de la situación de violencia vivida                                                 571 non-null    object
#  25  Cambios en el comportamiento digital luego de lo sucedido                                       571 non-null    object
#  26  Efectos de haber vivido estas situaciones de violencia                                          414 non-null    object
#  27  Si conto lo sucedido a alguien                                                                  571 non-null    object
#  28  Si sabe como denunciar situaciones de violencia de género digital                               1422 non-null   object
#  29  Si Realizo alguna formación o se interiorizo sobre seguridad digital en los últimos cinco años  1422 non-null   object
#  30  Tipo de medidas útiles para prevenir o responder a la violencia de género digital               1422 non-null   object
#  31  Nivel de conocimiento o entendimiento de medidas de seguridad digital                           1415 non-null   float64
#  32   Nivel de preparación para proteger su privacidad                                               1422 non-null   object
#  33  Vivencias en internet y violencia de género facilitada por la tecnología                        430 non-null    object
#  34  Región                                                                                          1422 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(33)
# memory usage: 389.0+ KB

# %% [markdown]
# ## Visualizaciones

# %%
df_sd_total_provincias = df_sd.groupby('Provincia', as_index=False)['Si existe conocimiento de la persona o grupo que llevo a cabo la acción'].count()

df_sd_total_provincias = df_sd_total_provincias.sort_values('Si existe conocimiento de la persona o grupo que llevo a cabo la acción', ascending=True)

plt.figure(figsize=(10,6))

plt.barh(
    df_sd_total_provincias['Provincia'],
    df_sd_total_provincias['Si existe conocimiento de la persona o grupo que llevo a cabo la acción']
)

plt.xlabel('Cantidad de situaciones de violencia de género en entornos digitales con conocimiento de los agresores')
plt.ylabel('Provincias')
plt.title('Cantidad total de situaciones de violencia de género con conocimiento de los agresores')
plt.grid(axis='x')

for index, value in enumerate(df_sd_total_provincias['Si existe conocimiento de la persona o grupo que llevo a cabo la acción']):
    plt.text(value, index, str(value), va='center')

plt.show()

# %%
df_sd_total_regiones = df_sd.groupby('Región', as_index=False)['Si existe conocimiento de la persona o grupo que llevo a cabo la acción'].count()

df_sd_total_regiones = df_sd_total_regiones.sort_values('Si existe conocimiento de la persona o grupo que llevo a cabo la acción', ascending=True)

plt.figure(figsize=(10,6))

plt.barh(
    df_sd_total_regiones['Región'],
    df_sd_total_regiones['Si existe conocimiento de la persona o grupo que llevo a cabo la acción']
)

plt.xlabel('Cantidad de situaciones de violencia de género en entornos digitales con conocimiento de los agresores')
plt.ylabel('Regiones')
plt.title('Cantidad total de situaciones de violencia de género con conocimiento de los agresores')
plt.grid(axis='x')

for index, value in enumerate(df_sd_total_regiones['Si existe conocimiento de la persona o grupo que llevo a cabo la acción']):
    plt.text(value, index, str(value), va='center')

plt.show()

# %%
df_pivot_provincia = df_sd.groupby(['Provincia', 'Si existe conocimiento de la persona o grupo que llevo a cabo la acción']).size().unstack(fill_value=0)

df_pivot_provincia['Total'] = df_pivot_provincia.sum(axis=1)
df_pivot_provincia = df_pivot_provincia.sort_values('Total', ascending=True).drop(columns='Total')

ax = df_pivot_provincia.plot(kind='barh', stacked=True, figsize=(12, 8), colormap='viridis')

plt.xlabel('Cantidad de situaciones de violencia de género en entornos digitales con conocimiento de los agresores')
plt.ylabel('Provincias')
plt.title('Cantidad total de situaciones de violencia de género con conocimiento de los agresores por provincia')
plt.legend(title='Nivel de conocimiento', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='x', linestyle='--', alpha=0.7)

for p in ax.patches:
    width = p.get_width()
    if width > 0:
        ax.annotate(str(int(width)),
                    (p.get_x() + width/2, p.get_y() + p.get_height()/2),
                    ha='center', va='center', fontsize=9, color='white')

plt.tight_layout()
plt.show()

# %%
df_pivot_región = df_sd.groupby(['Región', 'Si existe conocimiento de la persona o grupo que llevo a cabo la acción']).size().unstack(fill_value=0)

df_pivot_región['Total'] = df_pivot_región.sum(axis=1)
df_pivot_región = df_pivot_región.sort_values('Total', ascending=True).drop(columns='Total')

ax = df_pivot_región.plot(kind='barh', stacked=True, figsize=(12, 8), colormap='viridis')

plt.xlabel('Cantidad de situaciones de violencia de género en entornos digitales con conocimiento de los agresores')
plt.ylabel('Regiones')
plt.title('Cantidad total de situaciones de violencia de género con conocimiento de los agresores por región')
plt.legend(title='Nivel de conocimiento', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='x', linestyle='--', alpha=0.7)

for p in ax.patches:
    width = p.get_width()
    if width > 0:
        ax.annotate(str(int(width)),
                    (p.get_x() + width/2, p.get_y() + p.get_height()/2),
                    ha='center', va='center', fontsize=9, color='white')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Guardado y descarga de los dataframes

# %%
df_sd.to_excel('df.sd.xlsx', index=False)
